# %%
# Analizy danych
# kilka linijek kodu, które zapewniają, 
# że nasze wizualizacje będą wykreślane „inline” z naszym kodem 
# i że będą miały ładną, wyraźną jakość.
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

df_pokemon = pd.read_csv("pokemon_lok.csv")
# df_pokemon.head(3)

# %%
fig = px.histogram(df_pokemon, x="Defense", color="Attack")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig = px.histogram(df_pokemon, x="Defense", color="Attack")
#       2 fig.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histogram'
