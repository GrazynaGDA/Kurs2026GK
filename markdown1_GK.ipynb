# %% [markdown]
# ##  <span style="color: blue;">Taka historia.</span>
#
# Dawno temu, w ubiegłym wieku po **Gdańsku** jeździły furmanki i powozy ciągnięte przez ~~osły~~ konie.
# Żeby taki zestaw uruchomić, to woźnica musiał krzyknąć
# >Wiooooo !!!
#
# Konie żywiono:
# - sianem
# - owsem
# - marchewką
# - jabłkami
# - otrębami
#
# Na terenie Gdańska było wiele stajni, między innymi wojskowe. Budynek związany z jedną z nich jest na ulicy [Aksamitnej](https://www.gdansk.pl/urzad-miejski/ul-aksamitna-4a-dawna-stajnia-w-zespole-koszar-artyleryjskich-ii-zawiadomienie-o-wlaczeniu-nowej-karty,a,290195).
#
# ![1](Aksamitna.jpg)
# Kuźnia pozostająca do dziś, powstała pod koniec XIX wieku

# %% [markdown]
# ##  <span style="color: blue;">Taka tabelka motoryzacyjna.</span>
#
# | marka | model | jaki | do czego |
# | :---: | :---: | ---: | :--- |
# | Suzuki | Vitara | 😊 | w teren |
# | Suzuki | Swift | 😋 | do miasta |
# | Syrena | 105 | ![os_ico.ico](attachment:os_ico.ico) | do wspomnień |
#
# ##  <span style="color: yellow;">Taka tabelka matematyczna.</span>
#
# | wzór | do czego |
# | :---: | :--- |
# | $\sqrt{\frac{\color{red}{Delta}}{\color{yellow}{Gamma}}}$  | łatwy |
# | $\sqrt{\frac{\color{red}{Delta}}{\color{yellow}{Gamma}}}$ = $\sqrt{\frac{\Delta}{\Gamma}}$ | trudny |
# | $\int_{{\color{orange}stąd}}^{\color{brown}{końca}} f(Wiedza) \, dx$ | fantazyjny |
# | ${\color{black}\sqrt{\frac{Delta}{Gamma}}}$  | niewidoczny |
