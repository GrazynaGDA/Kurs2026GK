# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([['1','2','3','4'], ['a','s','d','f'], ['weq','wer','wewe','qww']],
                   columns=['k1','k2','k3','k4'], 
                   index=['x','y','xy'])
df.head(2)
# Out:
#   k1 k2 k3 k4
# x  1  2  3  4
# y  a  s  d  f

# %%
# loc chce nazwy indeksu
df.loc['x']
# Out:
# k1    1
# k2    2
# k3    3
# k4    4
# Name: x, dtype: str

# %%
df.iloc[2:3]
# Out:
#      k1   k2    k3   k4
# xy  weq  wer  wewe  qww

# %%
df.iloc[:,[0,1,2,3]]
# Out:
#      k1   k2    k3   k4
# x     1    2     3    4
# y     a    s     d    f
# xy  weq  wer  wewe  qww

# %%
df.loc[df['k1']=='a']
# Out:
#   k1 k2 k3 k4
# y  a  s  d  f

# %%
df.query('k2=="2"')
# Out:
#   k1 k2 k3 k4
# x  1  2  3  4

# %%
df.drop(columns=['k1'])
# Out:
#      k2    k3   k4
# x     2     3    4
# y     s     d    f
# xy  wer  wewe  qww

# %%
df['kk1'] = df['k2']+df['k3']
df
# Out:
#      k1   k2    k3   k4      kk1
# x     1    2     3    4       23
# y     a    s     d    f       sd
# xy  weq  wer  wewe  qww  werwewe
