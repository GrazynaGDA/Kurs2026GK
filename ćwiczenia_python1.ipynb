# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([['1','2','3','4'], ['a','s','d','f'], ['weq','wer','wewe','qww']],
                   columns=['k1','k2','k3','k4'], 
                   index=['x','y','xy'])
df.head(2)
# Out:
#   k1 k2 k3 k4
# x  1  2  3  4
# y  a  s  d  f
